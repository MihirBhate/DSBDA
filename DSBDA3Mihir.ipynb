# %% [markdown]
# <a href="https://colab.research.google.com/github/MihirBhate/DSBDA/blob/DSBDA/DSBDA3Mihir.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('company_employee_details.csv')

# Group by the categorical variable (e.g., age_group) and calculate summary statistics for the numeric variable (e.g., income)
grouped_stats = df.groupby('age')['salary']

# Calculate basic statistics for each numeric column within each species group
mean_values = grouped_stats.mean()
std_dev_values = grouped_stats.std()
min_values = grouped_stats.min()
max_values = grouped_stats.max()

# Display the calculated values
print("Mean Values:")
print(mean_values)

print("\nStandard Deviation Values:")
print(std_dev_values)

print("\nMaximum Values:")
print(max_values)

print("\nMinimum Values:")
print(min_values)
# Out:
# Mean Values:
# age
# 30    86397.999275
# 31    84207.021683
# 32    86774.060996
# 33    87794.418634
# 34    86764.355804
# 35    86496.385722
# 36    85816.271310
# 37    83486.413020
# 38    86970.203296
# 39    88281.377793
# 40    86743.983284
# 41    86371.300781
# 42    89664.723313
# 43    87096.402705
# 44    90826.703831
# 45    84127.114538
# 46    88702.001635
# 47    86074.533971
# 48    93234.493683
# 49    90376.082325
# Name: salary, dtype: float64
#
# Standard Deviation Values:
# age
# 30    28460.351815
# 31    29001.124038
# 32    27604.377404
# 33    29195.927613
# 34    27709.652529
# 35    29853.072265
# 36    28261.532876
# 37    26269.108948
# 38    27820.328427
# 39    28670.180267
# 40    28667.794894
# 41    28680.648876
# 42    30011.062229
# 43    28927.676714
# 44    28850.128108
# 45    28349.651068
# 46    28428.991932
# 47    24793.471675
# 48    28522.432734
# 49    27893.050066
# Name: salary, dtype: float64
#
# Maximum Values:
# age
# ...

# %%
#Shortcut
import pandas as pd

# Load the dataset
df = pd.read_csv('company_employee_details.csv')

# Group by the categorical variable (e.g., age_group) and calculate summary statistics for the numeric variable (e.g., income)
grouped_stats = df.groupby('age')['salary'].describe()

# Display the summary statistics
print(grouped_stats)
# Out:
#      count          mean           std      min           25%           50%  \
# age
# 30   778.0  86397.999275  28460.351815  40000.0  66373.265868  85439.763111
# 31   185.0  84207.021683  29001.124038  40000.0  59673.083424  82025.369532
# 32   206.0  86774.060996  27604.377404  40000.0  66346.000655  83522.054991
# 33   234.0  87794.418634  29195.927613  40000.0  63810.725145  88904.432783
# 34   240.0  86764.355804  27709.652529  40000.0  67190.551200  86566.652776
# 35   274.0  86496.385722  29853.072265  40000.0  64082.253452  85790.247197
# 36   273.0  85816.271310  28261.532876  40000.0  64778.385221  85457.698943
# 37   249.0  83486.413020  26269.108948  40000.0  64992.218327  80989.092702
# 38   274.0  86970.203296  27820.328427  40000.0  68129.989114  85803.994255
# 39   267.0  88281.377793  28670.180267  40000.0  66468.532479  88734.549895
# 40   253.0  86743.983284  28667.794894  40000.0  63059.314691  88195.872465
# ...

# %%
#Shortcut
import pandas as pd

# Load the Iris dataset from a CSV file
df = pd.read_csv('Iris.csv')

# Group by species and calculate basic statistical details
species_stats = df.groupby('Species').describe()

# Display the statistical details for each species
print(species_stats)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#                    Id                                                        \
#                 count   mean       std    min     25%    50%     75%    max
# Species
# Iris-setosa      50.0   25.5  14.57738    1.0   13.25   25.5   37.75   50.0
# Iris-versicolor  50.0   75.5  14.57738   51.0   63.25   75.5   87.75  100.0
# Iris-virginica   50.0  125.5  14.57738  101.0  113.25  125.5  137.75  150.0
#
#                 SepalLengthCm         ... PetalLengthCm      PetalWidthCm  \
# ...

# %%
import pandas as pd

df = pd.read_csv('Iris.csv')

# Group by species
grouped = df.groupby('Species')

# Calculate basic statistics for each numeric column within each species group
mean_values = grouped.mean()
median_values = grouped.median()
std_dev_values = grouped.std()
min_values = grouped.min()
max_values = grouped.max()

# Calculate percentiles for each numeric column within each species group
percentiles = grouped.quantile([0.25, 0.50, 0.75])

# Display the calculated values
print("Mean Values:")
print(mean_values)

print("\nMedian Values:")
print(median_values)

print("\nStandard Deviation Values:")
print(std_dev_values)

print("\nMinimum Values:")
print(min_values)

print("\nMaximum Values:")
print(max_values)

print("\nPercentiles:")
print(percentiles)
# Out:
# Mean Values:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026
#
# Median Values:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5            5.0           3.4           1.50
# Iris-versicolor   75.5            5.9           2.8           4.35
# Iris-virginica   125.5            6.5           3.0           5.55
#
#                  PetalWidthCm
# Species
# Iris-setosa               0.2
# Iris-versicolor           1.3
# Iris-virginica            2.0
#
# Standard Deviation Values:
#                        Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# ...
